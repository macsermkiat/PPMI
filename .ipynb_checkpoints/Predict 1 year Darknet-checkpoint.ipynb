# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *
#from fastai.transforms import *
from fastai.conv_learner import *
#from fastai.model import *
#from fastai.dataset import *
#from fastai.sgdr import *
#from fastai.plots import *

# %%
print(torch.__version__)
# Out:
# 0.4.0

# %%
PATH = "./"

# %%
import pydicom
import glob
import os
import numpy
import seaborn as sns
from itertools import chain

# %%
lstFilesDCM = []  # create an empty list
'''for dirName, subdirList, fileList in os.walk(PathDicom):
    for filename in fileList:
        if ".dcm" in filename.lower():  # check whether the file's DICOM
            lstFilesDCM.append(os.path.join(dirName,filename))'''
# Out:
# 'for dirName, subdirList, fileList in os.walk(PathDicom):\n    for filename in fileList:\n        if ".dcm" in filename.lower():  # check whether the file\'s DICOM\n            lstFilesDCM.append(os.path.join(dirName,filename))'

# %%
metadata = pd.read_csv(f'{PATH}PPMI.csv')

# %%
metadata[0:5]
# Out:
#    Image Data ID  Subject    Group Sex  Age  Visit Modality  \
# 0         388628     4140  Control   M   76      0    SPECT
# 1         388627     4139  Control   M   81      0    SPECT
# 2         388626     4137       PD   M   70      0    SPECT
# 3         388625     4136       PD   M   56      0    SPECT
# 4         451290     4135       PD   M   68      5    SPECT
#
#              Description       Type   Acq Date Format Downloaded
# 0  Reconstructed DaTSCAN  Processed  4/09/2013    DCM  5/27/2018
# 1  Reconstructed DaTSCAN  Processed  3/19/2013    DCM  5/27/2018
# 2  Reconstructed DaTSCAN  Processed  4/02/2013    DCM  5/27/2018
# 3  Reconstructed DaTSCAN  Processed  2/13/2013    DCM  5/27/2018
# 4  Reconstructed DaTSCAN  Processed  2/18/2014    DCM  5/27/2018

# %%
#Shuffle data
metadata = metadata.sample(frac=1).reset_index(drop=True)

# %%
metadata[0:5]
# Out:
#    Image Data ID  Subject    Group Sex  Age  Visit Modality  \
# 0         388627     4139  Control   M   81      0    SPECT
# 1         419283     4056       PD   M   65      5    SPECT
# 2         418889     3150       PD   F   59      7    SPECT
# 3         468277     3629       PD   M   56      7    SPECT
# 4         388617     4122       PD   M   64      0    SPECT
#
#              Description       Type    Acq Date Format Downloaded
# 0  Reconstructed DaTSCAN  Processed   3/19/2013    DCM  5/27/2018
# 1  Reconstructed DaTSCAN  Processed   6/13/2013    DCM  5/27/2018
# 2  Reconstructed DaTSCAN  Processed  11/02/2012    DCM  5/27/2018
# 3  Reconstructed DaTSCAN  Processed  10/09/2014    DCM  5/27/2018
# 4  Reconstructed DaTSCAN  Processed   2/06/2013    DCM  5/27/2018

# %%
len(lstFilesDCM)
# Out:
# 1569

# %%
ptID = []
for i in lstFilesDCM:
    j = i.split("_")[13].strip()
    j = int(j[1:7])
    ptID.append(j)
len(ptID)
# Out:
# 1569

# %%
p ={}
for o in ptID:
    for k in metadata.iloc[:,0]:
        if o == k:
            p[o] = metadata.loc[metadata['Image Data ID'] == k, 'Group'].tolist()[0]
len(p)
# Out:
# 1569

# %%
df = metadata[['Image Data ID','Group']].set_index('Image Data ID')
for index, rows in df.iterrows():
    for i in lstFilesDCM:
        j = i.split("_")[13].strip()
        j = int(j[1:7])
        if index == j:
            df.loc[df.index == j, "Filenames"] = i

# %%
#Check duplicate item
bg = []
for i in lstFilesDCM:
    for index, rows in df.iterrows():
        j = i.split("_")[13].strip()
        j = int(j[1:7])
        if j == index:
            bg.append(index)
print( [item for item, count in collections.Counter(bg).items() if count > 1] )

# %%
lstFilesDCM = df['Filenames'].values

# %%
lstFilesDCM = lstFilesDCM.tolist()

# %%
df.sample(frac=0.2, axis=0)
# Out:
#                  Group                                          Filenames
# Image Data ID
# 504428              PD  ./PPMI 5/3132/Reconstructed_DaTSCAN/2015-04-22...
# 388477              PD  ./PPMI 3/3132/Reconstructed_DaTSCAN/2013-03-01...
# 442969              PD  ./PPMI 3.5/3392/Reconstructed_DaTSCAN/2014-05-...
# 419258              PD  ./PPMI 4/3661/Reconstructed_DaTSCAN/2013-08-29...
# 389264              PD  ./PPMI 3/3867/Reconstructed_DaTSCAN/2012-05-16...
# 358128              PD  ./PPMI 3/3455/Reconstructed_DaTSCAN/2012-03-13...
# 846847              PD  ./PPMI 3/3814/Reconstructed_DaTSCAN/2013-12-10...
# 767590              PD  ./PPMI 9/3224/Reconstructed_DaTSCAN/2016-04-20...
# 338784              PD  ./PPMI 4/3575/Reconstructed_DaTSCAN/2011-09-15...
# 341205              PD  ./PPMI 3.5/3051/Reconstructed_DaTSCAN/2010-10-...
# 358121              PD  ./PPMI 6/3207/Reconstructed_DaTSCAN/2012-04-11...
# 418926              PD  ./PPMI 3.5/3559/Reconstructed_DaTSCAN/2013-03-...
# 339003              PD  ./PPMI 7/3621/Reconstructed_DaTSCAN/2011-12-21...
# 339936              PD  ./PPMI 7/3500/Reconstructed_DaTSCAN/2010-10-28...
# 847144              PD  ./PPMI 7/3789/Reconstructed_DaTSCAN/2016-11-30...
# 418880              PD  ./PPMI 8/3056/Reconstructed_DaTSCAN/2013-01-18...
# 337836         Control  ./PPMI 7/3854/Reconstructed_DaTSCAN/2011-05-18...
# 341041              PD  ./PPMI 3.5/3205/Reconstructed_DaTSCAN/2011-07-...
# 339915              PD  ./PPMI 3.5/3366/Reconstructed_DaTSCAN/2011-07-...
# 418889              PD  ./PPMI 4/3150/Reconstructed_DaTSCAN/2012-11-02...
# 688489              PD  ./PPMI 7/3364/Reconstructed_DaTSCAN/2015-05-13...
# 418656              PD  ./PPMI 3/3174/Reconstructed_DaTSCAN/2013-04-09...
# 355249              PD  ./PPMI 8/4071/Reconstructed_DaTSCAN/2012-05-24...
# 504426              PD  ./PPMI 4/3122/Reconstructed_DaTSCAN/2014-07-25...
# 388147         Control  ./PPMI/3796/Reconstructed_DaTSCAN/2013-05-15_1...
# 446126              PD  ./PPMI 7/3446/Reconstructed_DaTSCAN/2014-04-02...
# 341258              PD  ./PPMI 3.5/3863/Reconstructed_DaTSCAN/2012-02-...
# 388471              PD  ./PPMI 6/3086/Reconstructed_DaTSCAN/2013-03-19...
# 418913              PD  ./PPMI 3/3417/Reconstructed_DaTSCAN/2013-03-27...
# 449043              PD  ./PPMI 5/4058/Reconstructed_DaTSCAN/2014-07-31...
# ...                ...                                                ...
# 418883              PD  ./PPMI 3.5/3060/Reconstructed_DaTSCAN/2013-03-...
# 358112              PD  ./PPMI 3.5/3002/Reconstructed_DaTSCAN/2012-04-...
# 341201              PD  ./PPMI 7/3014/Reconstructed_DaTSCAN/2011-10-25...
# 388552              PD  ./PPMI 6/3838/Reconstructed_DaTSCAN/2013-03-05...
# 847069              PD  ./PPMI 9/3823/Reconstructed_DaTSCAN/2016-06-07...
# 339015              PD  ./PPMI 9/3657/Reconstructed_DaTSCAN/2011-07-20...
# 363953         Control  ./PPMI 2/3816/Reconstructed_DaTSCAN/2012-12-04...
# 388494         Control  ./PPMI 9/3286/Reconstructed_DaTSCAN/2012-11-06...
# 343879              PD  ./PPMI/4024/Reconstructed_DaTSCAN/2012-07-03_1...
# 419877              PD  ./PPMI 7/3430/Reconstructed_DaTSCAN/2013-07-10...
# 355221         Control  ./PPMI 9/3662/Reconstructed_DaTSCAN/2012-08-29...
# 418467              PD  ./PPMI/3066/Reconstructed_DaTSCAN/2012-06-12_1...
# 504460              PD  ./PPMI/3910/Reconstructed_DaTSCAN/2015-01-06_1...
# 355935              PD  ./PPMI 5/3051/Reconstructed_DaTSCAN/2011-11-08...
# 436884              PD  ./PPMI 6/4113/Reconstructed_DaTSCAN/2014-03-19...
# 767602              PD  ./PPMI 8/3616/Reconstructed_DaTSCAN/2016-01-05...
# 418339              PD  ./PPMI 3/3111/Reconstructed_DaTSCAN/2012-05-22...
# 767697              PD  ./PPMI 8/3366/Reconstructed_DaTSCAN/2015-10-21...
# 767593              PD  ./PPMI 6/3308/Reconstructed_DaTSCAN/2015-12-02...
# 340347         Control  ./PPMI 3/3405/Reconstructed_DaTSCAN/2010-07-08...
# 449027              PD  ./PPMI 9/3625/Reconstructed_DaTSCAN/2014-05-21...
# 342183              PD  ./PPMI 3/3224/Reconstructed_DaTSCAN/2012-04-13...
# 341233         Control  ./PPMI/3103/Reconstructed_DaTSCAN/2010-10-21_1...
# 388585              PD  ./PPMI 8/4034/Reconstructed_DaTSCAN/2013-02-21...
# 419276              PD  ./PPMI 7/3954/Reconstructed_DaTSCAN/2013-01-22...
# 419265              PD  ./PPMI 6/3776/Reconstructed_DaTSCAN/2013-06-12...
# 419286              PD  ./PPMI 7/4091/Reconstructed_DaTSCAN/2013-08-13...
# 339912         Control  ./PPMI 8/3362/Reconstructed_DaTSCAN/2011-09-15...
# 418702              PD  ./PPMI 5/3773/Reconstructed_DaTSCAN/2013-03-14...
# 343857              PD  ./PPMI 7/3229/Reconstructed_DaTSCAN/2012-06-27...
#
# [314 rows x 2 columns]

# %%
up = pd.read_csv('comandfile.csv')

# %%
up.head()
# Out:
#    Image Data ID Group                                          Filenames  \
# 0         688484    PD  ./PPMI 5/3108/Reconstructed_DaTSCAN/2015-05-07...
# 1         446117    PD  ./PPMI/3308/Reconstructed_DaTSCAN/2014-02-12_1...
# 2         446109    PD  ./PPMI 9/3173/Reconstructed_DaTSCAN/2014-03-19...
# 3         341084    PD  ./PPMI 8/3951/Reconstructed_DaTSCAN/2011-09-28...
# 4         363942    PD  ./PPMI/3027/Reconstructed_DaTSCAN/2012-11-28_1...
#
#       TOTAL3    1YR   2YR   3YR   TOTAL3.1
# 0  10.500000  18.00  25.0   NaN  10.500000
# 1  19.666667  25.00  20.5  27.0  19.666667
# 2  24.500000  30.50  38.0  49.0  24.500000
# 3  14.000000  17.75  18.0  10.5  14.000000
# 4  26.000000  22.25  22.0  17.5  26.000000

# %%
up_df = up[['Image Data ID','TOTAL3','1YR','2YR','3YR','TOTAL3']].set_index('Image Data ID')

# %%
df1to4 = df.join(up_df)

# %%
df1to4 = df1to4.dropna(axis=0,subset=(['1YR']))

# %%
df1to4
# Out:
#       Image Data ID    Group  \
# 0            688484       PD
# 1            446117       PD
# 2            446109       PD
# 3            341084       PD
# 4            363942       PD
# 5            339933       PD
# 6            389231       PD
# 7            339900       PD
# 8            418918       PD
# 9            446135       PD
# 10           355200       PD
# 11           693014       PD
# 12           418357       PD
# 13           419256       PD
# 14           767594       PD
# 15           340398  Control
# 16           389262       PD
# 17           449434       PD
# 18           339897       PD
# 19           343886  Control
# 20           418899       PD
# 21           436869       PD
# 22           339563       PD
# 23           341225  Control
# 24           339540       PD
# 25           388467       PD
# 26           442972       PD
# 27           693017       PD
# 28           418368       PD
# 29           419261       PD
# ...             ...      ...
# 1361         419861       PD
# 1362         341063       PD
# 1363         418914       PD
# 1364         419253       PD
# 1365         388530       PD
# 1366         339914       PD
# 1367         354344  Control
# 1368         388549       PD
# 1369         449034       PD
# 1370         389271       PD
# 1371         436066       PD
# 1372         419575       PD
# 1373         418913       PD
# 1374         847069       PD
# 1375         389252       PD
# 1376         504834       PD
# 1377         388505  Control
# 1378         436857       PD
# 1379         418468       PD
# 1380         360607       PD
# 1381         419576       PD
# 1382         419252       PD
# 1383         418711       PD
# 1384         360624       PD
# 1385         446143       PD
# 1386         847144       PD
# 1387         767588       PD
# 1388         341249       PD
# 1389         442967       PD
# 1390         388578  Control
#
#                                               Filenames     TOTAL3        1YR  \
# 0     ./PPMI 5/3108/Reconstructed_DaTSCAN/2015-05-07...  10.500000  18.000000
# 1     ./PPMI/3308/Reconstructed_DaTSCAN/2014-02-12_1...  19.666667  25.000000
# 2     ./PPMI 9/3173/Reconstructed_DaTSCAN/2014-03-19...  24.500000  30.500000
# 3     ./PPMI 8/3951/Reconstructed_DaTSCAN/2011-09-28...  14.000000  17.750000
# 4     ./PPMI/3027/Reconstructed_DaTSCAN/2012-11-28_1...  26.000000  22.250000
# 5     ./PPMI 4/3467/Reconstructed_DaTSCAN/2011-11-30...  19.000000  19.250000
# 6     ./PPMI 6/3430/Reconstructed_DaTSCAN/2011-07-14...  11.333333  13.000000
# 7     ./PPMI 7/3314/Reconstructed_DaTSCAN/2012-01-11...  20.500000  22.000000
# 8     ./PPMI 5/3500/Reconstructed_DaTSCAN/2012-11-15...  34.000000  25.500000
# 9     ./PPMI 5/3660/Reconstructed_DaTSCAN/2014-04-25...  29.000000  38.500000
# 10    ./PPMI 9/3182/Reconstructed_DaTSCAN/2012-08-21...  32.000000  36.333333
# 11    ./PPMI 8/3418/Reconstructed_DaTSCAN/2015-05-19...  51.000000  49.000000
# 12    ./PPMI 6/3432/Reconstructed_DaTSCAN/2012-08-28...  37.750000  43.500000
# 13    ./PPMI 9/3625/Reconstructed_DaTSCAN/2013-04-02...  18.333333  11.500000
# 14    ./PPMI 2/3309/Reconstructed_DaTSCAN/2015-12-15...  15.000000  20.000000
# 15    ./PPMI 2/3450/Reconstructed_DaTSCAN/2010-10-21...   1.000000   2.000000
# 16    ./PPMI 3.5/3829/Reconstructed_DaTSCAN/2012-09-...  18.500000  19.250000
# 17    ./PPMI 4/3001/Reconstructed_DaTSCAN/2014-04-25...  36.500000  32.000000
# 18    ./PPMI/3311/Reconstructed_DaTSCAN/2011-12-14_1...  10.000000  11.000000
# 19    ./PPMI 9/4090/Reconstructed_DaTSCAN/2012-07-11...   0.000000   0.000000
# 20    ./PPMI 2/3207/Reconstructed_DaTSCAN/2013-02-27...  17.000000  18.000000
# 21    ./PPMI 3/3591/Reconstructed_DaTSCAN/2014-03-11...  19.000000  19.000000
# 22    ./PPMI/3567/Reconstructed_DaTSCAN/2011-08-25_1...  20.666667  26.500000
# 23    ./PPMI 8/3073/Reconstructed_DaTSCAN/2011-09-28...   2.000000   4.000000
# 24    ./PPMI 5/3522/Reconstructed_DaTSCAN/2011-12-07...  21.000000  17.250000
# 25    ./PPMI 7/3028/Reconstructed_DaTSCAN/2013-03-26...  29.500000  34.333333
# 26    ./PPMI 5/3589/Reconstructed_DaTSCAN/2014-05-16...  24.500000  23.500000
# 27    ./PPMI 4/3420/Reconstructed_DaTSCAN/2015-06-04...  14.000000  27.000000
# 28    ./PPMI 8/3609/Reconstructed_DaTSCAN/2012-06-19...  37.000000  37.000000
# 29    ./PPMI 3/3702/Reconstructed_DaTSCAN/2013-08-07...  12.333333  11.500000
# ...                                                 ...        ...        ...
# 1361  ./PPMI 3.5/3214/Reconstructed_DaTSCAN/2013-09-...  43.500000  39.500000
# 1362  ./PPMI 3.5/3253/Reconstructed_DaTSCAN/2011-01-...  29.666667  23.000000
# 1363  ./PPMI 2/3419/Reconstructed_DaTSCAN/2013-04-09...  12.000000  11.500000
# 1364  ./PPMI 3.5/3584/Reconstructed_DaTSCAN/2013-08-...  16.500000  32.000000
# 1365  ./PPMI/3708/Reconstructed_DaTSCAN/2013-01-30_1...  18.200000  10.000000
# 1366  ./PPMI 2/3365/Reconstructed_DaTSCAN/2011-07-28...  10.333333  11.000000
# 1367  ./PPMI 2/3804/Reconstructed_DaTSCAN/2012-07-24...   0.000000   0.000000
# 1368  ./PPMI 9/3835/Reconstructed_DaTSCAN/2013-01-22...  12.400000  13.500000
# 1369  ./PPMI 5/3781/Reconstructed_DaTSCAN/2014-07-09...  20.000000  19.000000
# 1370  ./PPMI 7/4054/Reconstructed_DaTSCAN/2012-06-12...  21.000000  37.500000
# 1371  ./PPMI 4/3132/Reconstructed_DaTSCAN/2014-03-27...  26.666667  29.000000
# 1372  ./PPMI 7/3785/Reconstructed_DaTSCAN/2013-11-20...  23.250000  13.000000
# 1373  ./PPMI 3/3417/Reconstructed_DaTSCAN/2013-03-27...  21.000000  25.000000
# 1374  ./PPMI 9/3823/Reconstructed_DaTSCAN/2016-06-07...  18.500000  18.000000
# 1375  ./PPMI 3.5/3700/Reconstructed_DaTSCAN/2012-07-...  18.333333  21.666667
# 1376  ./PPMI 9/3061/Reconstructed_DaTSCAN/2015-03-27...  30.000000   6.000000
# 1377  ./PPMI 3.5/3390/Reconstructed_DaTSCAN/2013-02-...   0.000000   0.000000
# 1378  ./PPMI 6/3131/Reconstructed_DaTSCAN/2014-03-06...  44.000000  48.000000
# 1379  ./PPMI 2/3068/Reconstructed_DaTSCAN/2012-09-21...  35.666667  39.500000
# 1380  ./PPMI 5/3083/Reconstructed_DaTSCAN/2012-10-10...  17.000000  18.000000
# 1381  ./PPMI 5/3787/Reconstructed_DaTSCAN/2013-10-30...  10.750000  11.000000
# 1382  ./PPMI 6/3532/Reconstructed_DaTSCAN/2013-04-17...  17.666667  16.000000
# 1383  ./PPMI 8/4020/Reconstructed_DaTSCAN/2013-03-29...  31.500000  29.000000
# 1384  ./PPMI 2/4101/Reconstructed_DaTSCAN/2012-11-14...  26.000000  20.750000
# 1385  ./PPMI 8/4019/Reconstructed_DaTSCAN/2014-03-07...  20.000000  18.500000
# 1386  ./PPMI 7/3789/Reconstructed_DaTSCAN/2016-11-30...  32.000000  43.000000
# 1387  ./PPMI/3220/Reconstructed_DaTSCAN/2015-12-10_1...  23.500000  27.500000
# 1388  ./PPMI 5/3532/Reconstructed_DaTSCAN/2012-02-17...  24.000000  17.666667
# 1389  ./PPMI 9/3028/Reconstructed_DaTSCAN/2014-06-10...  34.333333  41.500000
# 1390  ./PPMI 9/3969/Reconstructed_DaTSCAN/2013-02-20...   0.000000   0.000000
#
#             2YR   3YR   TOTAL3.1
# 0     25.000000   NaN  10.500000
# 1     20.500000  27.0  19.666667
# 2     38.000000  49.0  24.500000
# 3     18.000000  10.5  14.000000
# 4     22.000000  17.5  26.000000
# 5     19.500000  22.5  19.000000
# 6     17.500000   9.5  11.333333
# 7     29.000000   NaN  20.500000
# 8     30.500000  35.5  34.000000
# 9     30.000000   NaN  29.000000
# 10    27.500000  11.5  32.000000
# 11    48.000000   NaN  51.000000
# 12    42.500000  40.0  37.750000
# 13    15.500000   6.0  18.333333
# 14          NaN  29.0  15.000000
# 15     0.000000   NaN   1.000000
# 16    15.500000  11.0  18.500000
# 17    33.000000   NaN  36.500000
# 18    16.000000  12.0  10.000000
# 19     0.000000   0.0   0.000000
# 20    23.500000  18.0  17.000000
# 21    21.500000  19.0  19.000000
# 22    21.666667  23.5  20.666667
# 23     1.000000   1.0   2.000000
# 24    28.500000  26.5  21.000000
# 25    41.500000  40.0  29.500000
# 26    17.000000   NaN  24.500000
# 27    22.000000   NaN  14.000000
# 28    36.500000  37.5  37.000000
# 29    19.500000  12.0  12.333333
# ...         ...   ...        ...
# 1361  40.500000  43.5  43.500000
# 1362        NaN   NaN  29.666667
# 1363  16.500000  15.0  12.000000
# 1364  31.000000   NaN  16.500000
# 1365  12.500000  19.0  18.200000
# 1366  11.000000  15.0  10.333333
# 1367   0.000000   0.0   0.000000
# 1368  30.000000  27.0  12.400000
# 1369  24.500000  28.5  20.000000
# 1370  36.000000  50.0  21.000000
# 1371  35.500000  24.0  26.666667
# 1372  13.000000   9.5  23.250000
# 1373  30.000000  31.0  21.000000
# 1374        NaN   NaN  18.500000
# 1375  20.500000  14.0  18.333333
# 1376   5.000000  14.0  30.000000
# 1377        NaN   NaN   0.000000
# 1378  50.500000   NaN  44.000000
# 1379  36.000000  37.0  35.666667
# 1380  23.500000   6.5  17.000000
# 1381  10.000000  19.5  10.750000
# 1382  15.000000  22.0  17.666667
# 1383  38.500000  23.0  31.500000
# 1384  18.000000  21.5  26.000000
# 1385  25.500000  18.0  20.000000
# 1386        NaN   NaN  32.000000
# 1387  32.000000   NaN  23.500000
# 1388  16.000000  15.0  24.000000
# 1389  40.000000  54.0  34.333333
# 1390   0.000000   3.0   0.000000
#
# [1391 rows x 8 columns]

# %%
df1to4.to_csv('comandfile.csv')

# %%
df1to4 = pd.read_csv('comandfile.csv')

# %%
df1to4.loc[df1to4['Sex']=='F', 'Sex']=0
df1to4.loc[df1to4['Sex']=='M', 'Sex']=1

# %%
df1to4 = df1to4[~df1to4.Group.str.contains('Control')]

# %%
df1to4 = df1to4[~df1to4.TOTAL3.isnull()]

# %%
df1to4.any().isnull()
# Out:
# Image Data ID    False
# Group            False
# Subject          False
# Age              False
# Sex              False
# Filenames        False
# TOTAL3           False
# 1YR              False
# 2YR              False
# 3YR              False
# TOTAL3.1         False
# dtype: bool

# %%
sns.distplot(df1to4['TOTAL3'] , bins=30, kde=False, axlabel="Current Motor Score")
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df1to4['1YR'] , bins=30, kde=False, axlabel="Motor Score after 1 Year Treatment/Follow up")
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
from sklearn.cluster import KMeans

# Number of clusters
kmeans = KMeans(n_clusters=3)
# Fitting the input data
kmeans = kmeans.fit(X)
# Getting the cluster labels
labels = kmeans.predict(X)
# Centroid values
centroids = kmeans.cluster_centers_

# %%
sns.pairplot(df1to4[['Age','Sex','TOTAL3','1YR']])

# %%
from sklearn.model_selection import train_test_split
X_train_tmp, X_test_tmp, param_train_tmp, param_test_tmp, y_train_tmp, y_test_tmp = train_test_split(df1to4, df1to4['TOTAL3'], df1to4['1YR'], test_size=0.2)

from sklearn.model_selection import train_test_split
X_train_tmp, X_val_tmp, param_train_tmp, param_val_tmp, y_train_tmp, y_val_tmp = train_test_split(X_train_tmp, param_train_tmp, y_train_tmp, test_size=0.3)

# %%
lstFilesDCM_train = []  # create an empty list
lstFilesDCM_test = []
lstFilesDCM_val = []
lstFilesDCM_train = X_train_tmp['Filenames'].values
lstFilesDCM_train = lstFilesDCM_train.tolist()
lstFilesDCM_test = X_test_tmp['Filenames'].values
lstFilesDCM_test = lstFilesDCM_test.tolist()
lstFilesDCM_val = X_val_tmp['Filenames'].values
lstFilesDCM_val = lstFilesDCM_val.tolist()

# %% [markdown]
# For NORMAL Image

# %%
#Training Set

# %%
# loop through all the DICOM files
image_array_39_train =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_train.append(ds.pixel_array[39])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)

# %%
# loop through all the DICOM files
image_array_40_train =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_train.append(ds.pixel_array[40])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

# %%
# loop through all the DICOM files
image_array_41_train =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_train.append(ds.pixel_array[41])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)

# %%
#Stack up to made RGB, so we can use pretrain model
image_array_train = []
image_array_train = np.vstack((image_array_39_train, image_array_40_train, image_array_41_train))

# %%
#del(image_array_39_train, image_array_40_train, image_array_41_train)

# %%
image_array_train.shape
# Out:
# (2055, 109, 91)

# %%
image_array_train = image_array_train-4194.37731

# %%
#Validation set

# %%
'''# loop through all the DICOM files
image_array_39_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_val.append(ds.pixel_array[39])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)'''

# loop through all the DICOM files
image_array_40_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_val.append(ds.pixel_array[40])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

'''# loop through all the DICOM files
image_array_41_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_val.append(ds.pixel_array[41])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)'''

#Stack up to made RGB, so we can use pretrain model
'''image_array_val = np.vstack((
    np.stack([image_array_39_val, image_array_39_val, image_array_39_val], axis=3),
    np.stack([image_array_40_val, image_array_40_val, image_array_40_val], axis=3),
    np.stack([image_array_41_val, image_array_41_val, image_array_41_val], axis=3)))'''

image_array_val = np.asarray(image_array_40_val)
image_array_val = image_array_val-4194.37731
del(image_array_40_val)
image_array_val.shape
# Out:
# (294, 109, 91)

# %%
#Test set

# %%
'''# loop through all the DICOM files
image_array_39_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_test.append(ds.pixel_array[39])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)'''

# loop through all the DICOM files
image_array_40_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_test.append(ds.pixel_array[40])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

'''# loop through all the DICOM files
image_array_41_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_test.append(ds.pixel_array[41])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)'''

'''#Stack up to made RGB, so we can use pretrain model
image_array_test = np.vstack((
    np.stack([image_array_39_test, image_array_39_test, image_array_39_test], axis=3),
    np.stack([image_array_40_test, image_array_40_test, image_array_40_test], axis=3),
    np.stack([image_array_41_test, image_array_41_test, image_array_41_test], axis=3)))'''

image_array_test = np.asarray(image_array_40_test)
image_array_test = image_array_test-4194.37731
del(image_array_40_test)
image_array_test.shape
# Out:
# (245, 109, 91)

# %%
#Check matched data-result by Image ID number
lstFilesDCM_test[0:5]
# Out:
# ['./PPMI 4/3054/Reconstructed_DaTSCAN/2010-11-18_15_21_20.0/S117542/PPMI_3054_NM_Reconstructed_DaTSCAN_Br_20121019114727614_1_S117542_I341208.dcm',
#  './PPMI 9/4076/Reconstructed_DaTSCAN/2012-09-11_14_54_01.0/S170185/PPMI_4076_NM_Reconstructed_DaTSCAN_Br_20130116130954110_1_S170185_I355252.dcm',
#  './PPMI 2/3417/Reconstructed_DaTSCAN/2011-07-13_14_38_35.0/S117621/PPMI_3417_NM_Reconstructed_DaTSCAN_Br_20121016144843504_1_S117621_I340356.dcm',
#  './PPMI 8/3459/Reconstructed_DaTSCAN/2013-04-30_15_59_05.0/S215859/PPMI_3459_NM_Reconstructed_DaTSCAN_Br_20140410130527724_1_S215859_I419667.dcm',
#  './PPMI 9/3476/Reconstructed_DaTSCAN/2013-09-24_15_47_39.0/S215677/PPMI_3476_NM_Reconstructed_DaTSCAN_Br_20140409150401358_1_S215677_I419566.dcm']

# %%
X_test_tmp[0:5]
# Out:
#       Image Data ID Group                                          Filenames  \
# 1280         341208    PD  ./PPMI 4/3054/Reconstructed_DaTSCAN/2010-11-18...
# 481          355252    PD  ./PPMI 9/4076/Reconstructed_DaTSCAN/2012-09-11...
# 1080         340356    PD  ./PPMI 2/3417/Reconstructed_DaTSCAN/2011-07-13...
# 1301         419667    PD  ./PPMI 8/3459/Reconstructed_DaTSCAN/2013-04-30...
# 1285         419566    PD  ./PPMI 9/3476/Reconstructed_DaTSCAN/2013-09-24...
#
#          TOTAL3   1YR   2YR   3YR   TOTAL3.1
# 1280  15.000000  18.0  19.0  25.0  15.000000
# 481   33.500000  29.5  27.0  30.0  33.500000
# 1080  17.000000  21.0  21.0  25.0  17.000000
# 1301  36.500000  45.5  51.0  44.0  36.500000
# 1285  29.333333  33.5  50.0  56.0  29.333333

# %%
df = pd.concat([df1to4,df1to4,df1to4])

# %%
df1to4 = df

# %%
df1to4.loc[df1to4['Group']=='Control']
# Out:
# Empty DataFrame
# Columns: [Image Data ID, Group, Filenames, TOTAL3, 1YR, 2YR, 3YR, TOTAL3.1]
# Index: []

# %%
df1to4[df1to4.TOTAL3.isnull()]
# Out:
# Empty DataFrame
# Columns: [Image Data ID, Group, Filenames, TOTAL3, 1YR, 2YR, 3YR, TOTAL3.1]
# Index: []

# %%
y_train = y_train_tmp.values
y_train = np.hstack((y_train,y_train,y_train))
y_val = y_val_tmp.values
#y_val= np.hstack((y_val,y_val,y_val))
y_test = y_test_tmp.values
#y_val= np.hstack((y_val,y_val,y_val))

# %%
y_train = y_train.astype('float')
y_val = y_val.astype('float')
y_test = y_test.astype('float')

# %%
y_train.shape,y_val.shape,y_test.shape
# Out:
# ((2055,), (294,), (245,))

# %%
param_train = param_train_tmp.values
params = []
for i in param_train:
    stack = []
    stack.append(i)
    stack = stack*20
    params.append(stack)
param_train = np.asarray(params)
del(params)

# %%
param_val = param_val_tmp.values
params = []
for i in param_val:
    stack = []
    stack.append(i)
    stack = stack*20
    params.append(stack)
param_val = np.asarray(params)
del(params)

param_test = param_test_tmp.values
params = []
for i in param_test:
    stack = []
    stack.append(i)
    stack = stack*20
    params.append(stack)
param_test = np.asarray(params)
del(params)

# %%
param_train = np.vstack((param_train,param_train,param_train))

# %% [markdown]
# ### Load dataset

# %%
X_train = torch.utils.data.DataLoader(image_array_train, batch_size=16)
param_train = torch.utils.data.DataLoader(param_train, batch_size=16)
y_train = torch.utils.data.DataLoader(y_train, batch_size=16)
X_val = torch.utils.data.DataLoader(image_array_val, batch_size=16)
param_val = torch.utils.data.DataLoader(param_val, batch_size=16)
y_val = torch.utils.data.DataLoader(y_val, batch_size=16)
X_test = torch.utils.data.DataLoader(image_array_test, batch_size=16)
param_test = torch.utils.data.DataLoader(param_test, batch_size=16)
y_test = torch.utils.data.DataLoader(y_test, batch_size=16)

#del(image_array_train,image_array_val,image_array_test)
#del(X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp,param_train_tmp,param_val_tmp,param_test_tmp)

# %% [markdown]
# ### Darknet

# %%
def conv_layer(ni, nf, ks=3, stride=1):
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=ks, bias=False, stride=stride, padding=ks//2),
        nn.BatchNorm2d(nf, momentum=0.01),
        nn.LeakyReLU(negative_slope=0.1, inplace=False))

class ResLayer(nn.Module):
    def __init__(self, ni):
        super().__init__()
        self.conv1=conv_layer(ni, ni//2, ks=1)
        self.conv2=conv_layer(ni//2, ni, ks=3)
        
    def forward(self, x): return x.add_(self.conv2(self.conv1(x.clone())))

class Darknet(nn.Module):
    def make_group_layer(self, ch_in, num_blocks, stride=1):
        return [conv_layer(ch_in, ch_in*2,stride=stride)
               ] + [(ResLayer(ch_in*2)) for i in range(num_blocks)]

    def __init__(self, num_blocks, num_classes, nf=32):
        super().__init__()
        features = [conv_layer(1, nf, ks=3, stride=1)]
        for i,nb in enumerate(num_blocks):
            features += self.make_group_layer(nf, nb, stride=2-(i==1))
            nf *= 2                        
        features += [nn.AdaptiveAvgPool2d(1), Flatten()]        
        self.features = nn.Sequential(*features)
        fc1 = [nn.Linear(1044, 120), nn.LeakyReLU(negative_slope=0.1, inplace=False)]
        self.fc1 = nn.Sequential(*fc1)
        self.layers = nn.Sequential(nn.Linear(120,1))
        
    def forward(self, x, y):
        x = x.unsqueeze(1)
        x1 = self.features(x)
        x = torch.cat((x1,y),1)
        x = self.fc1(x)
        x = F.dropout(x, p=0.2, training=self.training)
        
        return self.layers(x)

# %%
m = Darknet([1,2,4,6,3], num_classes=1, nf=32)
m.double()
#m = nn.DataParallel(m, [1,2,3])
# Out:
# Darknet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (2): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (4): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (5): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (7): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (8): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (9): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (10): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (11): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (12): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (13): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (14): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (15): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (16): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (17): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (18): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (19): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (20): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (21): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (22): AdaptiveAvgPool2d(output_size=1)
#     (23): Flatten()
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1044, out_features=120, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#   )
#   (layers): Sequential(
#     (0): Linear(in_features=120, out_features=1, bias=True)
#   )
# )

# %%
optimizer = optim.Adam(m.parameters(), lr = 5e-5)
criterion = nn.MSELoss()
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.95)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
m.to(device)
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Train

# %%
losslog=[]
vallog=[]

# %%
def train(niter):
    for epoch in trange(niter):  # loop over the dataset multiple times
        running_loss = 0.0        

        m.train(True)
        scheduler.step()
        with tqdm(total=len(X_train)) as pbar:
            for i, (x, p, y) in enumerate(zip(X_train,param_train,y_train)):
                x,p,y = x.to(device), p.to(device),y.to(device)

                i += 1
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward + backward + optimize
                outputs = m(Variable(x),Variable(p))
                loss = criterion(outputs,Variable(y).unsqueeze(1))
                loss.backward()
                optimizer.step()

                pbar.update()

                # print statistics
                running_loss += loss.item()
                if i % 20 == 19:    # print every 20 mini-batches
                    print('[%d, %5d]  Train MSE loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 20))
                    losslog.append(running_loss/20)
                    running_loss = 0.0
                    
            #Eval
        with tqdm(total=len(X_val)) as pbar:
            with torch.no_grad():
                predicted =[]
                for i, ( x, p, y) in enumerate(zip(X_val,param_val,y_val)):
                    x,p,y = x.to(device), p.to(device),y.to(device)

                    # forward + backward + optimize
                    outputs = m(x,p)
                    pred = outputs.squeeze(1).cpu().numpy().tolist()
                    predicted.append(pred)
                    pbar.update()

                predicted = list(chain.from_iterable(predicted))
                valloss = ((predicted-y_val.dataset) **2).mean()
                #valloss = abs(predicted-y_val.dataset).sum()/len(y_val.dataset)
                vallog.append(valloss)
                print(f'Val MSE loss: {valloss}')
            
    print('Finished Training')
    return losslog,vallog

# %%
TT = train(3)
# Out:
#  15%|█▍        | 19/129 [02:05<12:16,  6.70s/it][1,    20]  Train MSE loss: 49.391
#  30%|███       | 39/129 [04:19<10:02,  6.69s/it][1,    40]  Train MSE loss: 57.508
#  46%|████▌     | 59/129 [06:33<07:48,  6.70s/it][1,    60]  Train MSE loss: 50.364
#  61%|██████    | 79/129 [08:47<05:34,  6.70s/it][1,    80]  Train MSE loss: 52.615
#  77%|███████▋  | 99/129 [11:01<03:20,  6.70s/it][1,   100]  Train MSE loss: 55.525
#  92%|█████████▏| 119/129 [13:15<01:06,  6.70s/it][1,   120]  Train MSE loss: 53.693
# 100%|██████████| 129/129 [14:19<00:00,  5.86s/it]
# 100%|██████████| 19/19 [00:42<00:00,  1.91s/it]Val MSE loss: 47.407897544665715
#
#  15%|█▍        | 19/129 [02:05<12:16,  6.69s/it][2,    20]  Train MSE loss: 52.104
#  30%|███       | 39/129 [04:19<10:02,  6.70s/it][2,    40]  Train MSE loss: 55.389
#  46%|████▌     | 59/129 [06:33<07:48,  6.69s/it][2,    60]  Train MSE loss: 51.592
#  61%|██████    | 79/129 [08:47<05:34,  6.69s/it][2,    80]  Train MSE loss: 53.391
#  77%|███████▋  | 99/129 [11:01<03:20,  6.69s/it][2,   100]  Train MSE loss: 56.589
#  92%|█████████▏| 119/129 [13:15<01:06,  6.70s/it][2,   120]  Train MSE loss: 55.210
# 100%|██████████| 129/129 [14:19<00:00,  5.86s/it]
# 100%|██████████| 19/19 [00:42<00:00,  1.91s/it]Val MSE loss: 49.47181756578603
#
#   3%|▎         | 4/129 [00:25<12:59,  6.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-34e00278dd51> in <module>()
# ----> 1 TT = train(3)
#
# <ipython-input-38-d411416bee58> in train(niter)
#      16                 loss = criterion(outputs,Variable(y).unsqueeze(1))
#      17                 loss.backward()
# ---> 18                 optimizer.step()
#      19
#      20                 pbar.update()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      91                 # Decay the first and second moment running average coefficient
#      92                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# ---> 93                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      94                 if amsgrad:
#      95                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
vallog
# Out:
# [44.62141113136483, 47.407897544665715, 49.47181756578603]

# %%
del (image_array_train,image_array_val,image_array_test)

# %%
# Out:
# Darknet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (2): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (4): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (5): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (7): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (8): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (9): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (10): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (11): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (12): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (13): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (14): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (15): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (16): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (17): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (18): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (19): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (20): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (21): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (22): AdaptiveAvgPool2d(output_size=1)
#     (23): Flatten()
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1044, out_features=120, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#   )
#   (layers): Sequential(
#     (0): Linear(in_features=120, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Validate

# %%
def test():
    with torch.no_grad():
        n = len(X_test)
        m.eval()
        predicted = []
        with tqdm(total=n) as pbar:
            for i, ( x, p, y) in enumerate(zip(X_test,param_test,y_test)):
                x,p,y = x.to(device), p.to(device),y.to(device)


                # forward + backward + optimize
                outputs = m(x,p)
                pred = outputs.squeeze(1).cpu().numpy().tolist()
                predicted.append(pred)
                pbar.update()
                
        predicted = list(chain.from_iterable(predicted))
        loss = ((predicted - y_test.dataset)**2).mean()
        #loss = abs(predicted-y_test.dataset).sum()/len(y_test.dataset)
        print(f'MSE loss: {loss}')
        df_y = pd.DataFrame(y_test.dataset,columns=['actual'])
        df_pred = pd.DataFrame(predicted,columns=['predicted'])
        df_pred = df_pred.join(df_y)
        sns.jointplot(x=df_pred['actual'], y=df_pred['predicted'])
        sns.distplot(y_test.dataset)
        sns.distplot(df_pred['predicted'])
    return df_pred, loss

# %%
TEST = test()
# Out:
# 100%|██████████| 16/16 [00:34<00:00,  1.85s/it]
# MSE loss: 47.97678651375663
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
TEST
# Out:
# (     predicted     actual
#  0    17.186001  18.000000
#  1    33.538565  29.500000
#  2    18.940728  21.000000
#  3    36.778069  45.500000
#  4    29.882505  33.500000
#  5    18.094533  16.333333
#  6    21.156747  15.000000
#  7    21.751598  26.000000
#  8    25.376211  15.500000
#  9    34.345140  35.500000
#  10   32.087543  15.000000
#  11   15.533410  14.000000
#  12   44.119402  46.500000
#  13   16.621464  20.500000
#  14   26.998539  26.000000
#  15   24.719280  12.500000
#  16   19.221853  24.000000
#  17   16.235541  16.500000
#  18   16.030954   6.000000
#  19   28.935947  37.333333
#  20   20.042542  23.000000
#  21   17.486822  14.750000
#  22   19.046555   9.500000
#  23   35.268471  31.000000
#  24   18.944218  23.750000
#  25   19.631054  14.333333
#  26   24.596464  31.000000
#  27   38.007706  47.500000
#  28   14.788844  12.333333
#  29   23.289145   9.000000
#  ..         ...        ...
#  215  18.061874  20.000000
#  216  30.870724  29.000000
#  217  26.344087  23.500000
#  218  19.319769  16.500000
#  219  21.648747  26.333333
#  220  30.968556  22.000000
#  221  18.493935  24.000000
#  222  27.292775  24.666667
#  223  24.516794   6.500000
#  224  28.143383  43.500000
#  225  22.397800  18.000000
#  226  25.296977  23.000000
#  227  26.675040  30.500000
#  228  30.549994  34.000000
#  229  31.567295  33.666667
#  230  34.123358  50.000000
#  231  18.631178  15.500000
#  232  15.787424  14.000000
#  233  42.915042  36.500000
#  234  24.654684   7.000000
#  235  21.642891  24.000000
#  236  29.079299  33.000000
#  237  22.992718  22.000000
#  238  34.927204  41.250000
#  239  13.235692  12.000000
#  240  11.387279   7.250000
#  241  22.028536  18.500000
#  242  24.927931  36.500000
#  243  15.953410  12.000000
#  244  25.152881  27.000000
#
#  [245 rows x 2 columns], 47.97678651375663)

# %%
model_save_path = './save_model/'

# %%
torch.save(m.state_dict(),'1_.pth')

# %%
m = Darknet([1,2,4,6,3], num_classes=1, nf=32)
m.double()
m.load_state_dict(torch.load('1_.pth'))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
m.to(device)
print(device)
# Out:
# cuda:0

# %%
sns.pairplot

# %%
sns.distplot(y_pred)

# %%
sns.distplot(y_test)
