# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *
#from fastai.transforms import *
from fastai.conv_learner import *
#from fastai.model import *
#from fastai.dataset import *
#from fastai.sgdr import *
#from fastai.plots import *

# %%
print(torch.__version__)
# Out:
# 0.4.0

# %%
PATH = "./"

# %%
import pydicom
import glob
import os
import numpy
import seaborn as sns
from itertools import chain

# %%
lstFilesDCM = []  # create an empty list
'''for dirName, subdirList, fileList in os.walk(PathDicom):
    for filename in fileList:
        if ".dcm" in filename.lower():  # check whether the file's DICOM
            lstFilesDCM.append(os.path.join(dirName,filename))'''
# Out:
# 'for dirName, subdirList, fileList in os.walk(PathDicom):\n    for filename in fileList:\n        if ".dcm" in filename.lower():  # check whether the file\'s DICOM\n            lstFilesDCM.append(os.path.join(dirName,filename))'

# %%
metadata = pd.read_csv(f'{PATH}PPMI.csv')

# %%
metadata[0:5]
# Out:
#    Image Data ID  Subject    Group Sex  Age  Visit Modality  \
# 0         388628     4140  Control   M   76      0    SPECT
# 1         388627     4139  Control   M   81      0    SPECT
# 2         388626     4137       PD   M   70      0    SPECT
# 3         388625     4136       PD   M   56      0    SPECT
# 4         451290     4135       PD   M   68      5    SPECT
#
#              Description       Type   Acq Date Format Downloaded
# 0  Reconstructed DaTSCAN  Processed  4/09/2013    DCM  5/27/2018
# 1  Reconstructed DaTSCAN  Processed  3/19/2013    DCM  5/27/2018
# 2  Reconstructed DaTSCAN  Processed  4/02/2013    DCM  5/27/2018
# 3  Reconstructed DaTSCAN  Processed  2/13/2013    DCM  5/27/2018
# 4  Reconstructed DaTSCAN  Processed  2/18/2014    DCM  5/27/2018

# %%
#Shuffle data
metadata = metadata.sample(frac=1).reset_index(drop=True)

# %%
metadata[0:5]
# Out:
#    Image Data ID  Subject    Group Sex  Age  Visit Modality  \
# 0         360618     3769  Control   M   71      0    SPECT
# 1         388617     4122       PD   M   64      0    SPECT
# 2         363956     3870       PD   F   41      0    SPECT
# 3         388601     4107       PD   M   71      0    SPECT
# 4         419581     3829       PD   F   68      5    SPECT
#
#              Description       Type    Acq Date Format Downloaded
# 0  Reconstructed DaTSCAN  Processed  10/25/2012    DCM  5/27/2018
# 1  Reconstructed DaTSCAN  Processed   2/06/2013    DCM  5/27/2018
# 2  Reconstructed DaTSCAN  Processed  11/29/2012    DCM  5/27/2018
# 3  Reconstructed DaTSCAN  Processed  12/21/2012    DCM  5/27/2018
# 4  Reconstructed DaTSCAN  Processed  10/01/2013    DCM  5/27/2018

# %%
for file in glob.glob(f'{PATH}PPMI*/**/Reconstructed_DaTSCAN/**/**/*.dcm'):
    lstFilesDCM.append(file)

# %%
len(lstFilesDCM)
# Out:
# 1569

# %%
ptID = []
for i in lstFilesDCM:
    j = i.split("_")[13].strip()
    j = int(j[1:7])
    ptID.append(j)
len(ptID)
# Out:
# 1569

# %%
p ={}
for o in ptID:
    for k in metadata.iloc[:,0]:
        if o == k:
            p[o] = metadata.loc[metadata['Image Data ID'] == k, 'Group'].tolist()[0]
len(p)
# Out:
# 1569

# %%
df = metadata[['Image Data ID','Group','Subject','Age','Sex']].set_index('Image Data ID')
for index, rows in df.iterrows():
    for i in lstFilesDCM:
        j = i.split("_")[13].strip()
        j = int(j[1:7])
        if index == j:
            df.loc[df.index == j, "Filenames"] = i

# %%
#Check duplicate item
bg = []
for i in lstFilesDCM:
    for index, rows in df.iterrows():
        j = i.split("_")[13].strip()
        j = int(j[1:7])
        if j == index:
            bg.append(index)
print( [item for item, count in collections.Counter(bg).items() if count > 1] )

# %%
lstFilesDCM = df['Filenames'].values

# %%
lstFilesDCM = lstFilesDCM.tolist()

# %%
df.sample(frac=0.2, axis=0)
# Out:
#                  Group  Subject  Age Sex  \
# Image Data ID
# 388578         Control     3969   80   F
# 767696              PD     3307   70   M
# 913228              PD     4109   71   M
# 418920              PD     3504   63   M
# 418669              PD     3307   67   M
# 360624              PD     4101   67   F
# 360615              PD     3633   69   F
# 342171              PD     3020   74   F
# 355210              PD     3473   55   F
# 342174              PD     3023   71   F
# 358148              PD     3559   39   M
# 419553              PD     3128   61   F
# 419858              PD     3209   70   M
# 504846              PD     3455   71   M
# 339896         Control     3310   65   M
# 418684              PD     3444   70   M
# 340347         Control     3405   63   F
# 355941              PD     3252   48   F
# 419855              PD     3162   63   M
# 419878              PD     3752   54   M
# 846856              PD     3128   64   F
# 389239              PD     3459   52   M
# 388627         Control     4139   81   M
# 767649              PD     3443   58   M
# 418654              PD     3125   47   M
# 504458              PD     3905   74   F
# 913182              PD     3664   66   F
# 495007              PD     3832   67   M
# 355943              PD     3352   53   M
# 913194              PD     3186   66   F
# ...                ...      ...  ...  ..
# 337839         Control     3859   60   M
# 355243              PD     4027   66   M
# 419657              PD     3061   55   F
# 355246         Control     4063   65   M
# 446108              PD     3119   66   M
# 388535         Control     3750   53   M
# 339900              PD     3314   77   F
# 418485              PD     3434   55   M
# 418496              PD     3608   47   M
# 389241              PD     3471   74   M
# 343882              PD     4056   64   M
# 355938              PD     3150   58   F
# 419280              PD     4026   76   M
# 419607              PD     4103   60   M
# 358124              PD     3415   63   M
# 847069              PD     3823   61   M
# 418705              PD     3815   63   M
# 339040              PD     4012   51   F
# 446133              PD     3622   64   M
# 418665              PD     3230   71   M
# 341055         Control     3219   70   M
# 449029              PD     3701   49   M
# 436079              PD     3914   59   M
# 337831              PD     3815   62   M
# 363964              PD     4106   72   M
# 341020              PD     3154   73   F
# 340403              PD     3506   67   F
# 449033              PD     3780   72   F
# 504434              PD     3589   77   F
# 419853              PD     3113   61   F
#
#                                                        Filenames
# Image Data ID
# 388578         ./PPMI 9/3969/Reconstructed_DaTSCAN/2013-02-20...
# 767696         ./PPMI 4/3307/Reconstructed_DaTSCAN/2015-11-05...
# 913228         ./PPMI 4/4109/Reconstructed_DaTSCAN/2017-02-24...
# 418920         ./PPMI 9/3504/Reconstructed_DaTSCAN/2013-01-23...
# 418669         ./PPMI 2/3307/Reconstructed_DaTSCAN/2012-11-07...
# 360624         ./PPMI 2/4101/Reconstructed_DaTSCAN/2012-11-14...
# 360615         ./PPMI 3/3633/Reconstructed_DaTSCAN/2012-11-01...
# 342171         ./PPMI 5/3020/Reconstructed_DaTSCAN/2012-03-27...
# 355210         ./PPMI 3/3473/Reconstructed_DaTSCAN/2012-08-15...
# 342174         ./PPMI 8/3023/Reconstructed_DaTSCAN/2012-05-01...
# 358148         ./PPMI 9/3559/Reconstructed_DaTSCAN/2012-03-15...
# 419553         ./PPMI 2/3128/Reconstructed_DaTSCAN/2013-09-18...
# 419858         ./PPMI 9/3209/Reconstructed_DaTSCAN/2013-07-31...
# 504846         ./PPMI 2/3455/Reconstructed_DaTSCAN/2015-03-19...
# 339896         ./PPMI 4/3310/Reconstructed_DaTSCAN/2011-12-08...
# 418684         ./PPMI/3444/Reconstructed_DaTSCAN/2013-03-14_1...
# 340347         ./PPMI 3/3405/Reconstructed_DaTSCAN/2010-07-08...
# 355941         ./PPMI 9/3252/Reconstructed_DaTSCAN/2011-12-21...
# 419855         ./PPMI 6/3162/Reconstructed_DaTSCAN/2013-09-24...
# 419878         ./PPMI 2/3752/Reconstructed_DaTSCAN/2013-08-28...
# 846856         ./PPMI/3128/Reconstructed_DaTSCAN/2016-10-13_1...
# 389239         ./PPMI 4/3459/Reconstructed_DaTSCAN/2011-08-18...
# 388627         ./PPMI 3/4139/Reconstructed_DaTSCAN/2013-03-19...
# 767649         ./PPMI 9/3443/Reconstructed_DaTSCAN/2016-02-24...
# 418654         ./PPMI 4/3125/Reconstructed_DaTSCAN/2013-07-02...
# 504458         ./PPMI 6/3905/Reconstructed_DaTSCAN/2014-10-22...
# 913182         ./PPMI 5/3664/Reconstructed_DaTSCAN/2017-04-18...
# 495007         ./PPMI 5/3832/Reconstructed_DaTSCAN/2014-11-25...
# 355943         ./PPMI 3/3352/Reconstructed_DaTSCAN/2012-02-15...
# 913194         ./PPMI 7/3186/Reconstructed_DaTSCAN/2017-05-11...
# ...                                                          ...
# 337839         ./PPMI 3.5/3859/Reconstructed_DaTSCAN/2011-08-...
# 355243         ./PPMI 7/4027/Reconstructed_DaTSCAN/2012-08-29...
# 419657         ./PPMI 5/3061/Reconstructed_DaTSCAN/2013-04-19...
# 355246         ./PPMI 6/4063/Reconstructed_DaTSCAN/2012-08-30...
# 446108         ./PPMI/3119/Reconstructed_DaTSCAN/2014-02-27_1...
# 388535         ./PPMI 5/3750/Reconstructed_DaTSCAN/2011-05-18...
# 339900         ./PPMI 7/3314/Reconstructed_DaTSCAN/2012-01-11...
# 418485         ./PPMI/3434/Reconstructed_DaTSCAN/2012-10-12_1...
# 418496         ./PPMI/3608/Reconstructed_DaTSCAN/2012-06-05_1...
# 389241         ./PPMI 3.5/3471/Reconstructed_DaTSCAN/2012-02-...
# 343882         ./PPMI 5/4056/Reconstructed_DaTSCAN/2012-06-21...
# 355938         ./PPMI/3150/Reconstructed_DaTSCAN/2011-11-30_1...
# 419280         ./PPMI 4/4026/Reconstructed_DaTSCAN/2013-09-18...
# 419607         ./PPMI 5/4103/Reconstructed_DaTSCAN/2014-01-10...
# 358124         ./PPMI 2/3415/Reconstructed_DaTSCAN/2012-04-13...
# 847069         ./PPMI 9/3823/Reconstructed_DaTSCAN/2016-06-07...
# 418705         ./PPMI 3.5/3815/Reconstructed_DaTSCAN/2012-11-...
# 339040         ./PPMI 7/4012/Reconstructed_DaTSCAN/2011-11-10...
# 446133         ./PPMI 8/3622/Reconstructed_DaTSCAN/2014-03-28...
# 418665         ./PPMI 3/3230/Reconstructed_DaTSCAN/2013-07-25...
# 341055         ./PPMI 4/3219/Reconstructed_DaTSCAN/2011-10-12...
# 449029         ./PPMI 3/3701/Reconstructed_DaTSCAN/2014-07-16...
# 436079         ./PPMI 8/3914/Reconstructed_DaTSCAN/2014-04-03...
# 337831         ./PPMI 6/3815/Reconstructed_DaTSCAN/2011-11-08...
# 363964         ./PPMI 2/4106/Reconstructed_DaTSCAN/2012-12-21...
# 341020         ./PPMI 4/3154/Reconstructed_DaTSCAN/2011-01-27...
# 340403         ./PPMI/3506/Reconstructed_DaTSCAN/2011-01-13_1...
# 449033         ./PPMI 3.5/3780/Reconstructed_DaTSCAN/2014-06-...
# 504434         ./PPMI 8/3589/Reconstructed_DaTSCAN/2015-02-18...
# 419853         ./PPMI 8/3113/Reconstructed_DaTSCAN/2013-07-12...
#
# [314 rows x 5 columns]

# %%
up = pd.read_csv('comandfile.csv')

# %%
up.head()
# Out:
#    Image Data ID Group                                          Filenames  \
# 0         688484    PD  ./PPMI 5/3108/Reconstructed_DaTSCAN/2015-05-07...
# 1         446117    PD  ./PPMI/3308/Reconstructed_DaTSCAN/2014-02-12_1...
# 2         446109    PD  ./PPMI 9/3173/Reconstructed_DaTSCAN/2014-03-19...
# 3         341084    PD  ./PPMI 8/3951/Reconstructed_DaTSCAN/2011-09-28...
# 4         363942    PD  ./PPMI/3027/Reconstructed_DaTSCAN/2012-11-28_1...
#
#       TOTAL3    1YR   2YR   3YR   TOTAL3.1
# 0  10.500000  18.00  25.0   NaN  10.500000
# 1  19.666667  25.00  20.5  27.0  19.666667
# 2  24.500000  30.50  38.0  49.0  24.500000
# 3  14.000000  17.75  18.0  10.5  14.000000
# 4  26.000000  22.25  22.0  17.5  26.000000

# %%
up_df = up[['Image Data ID','TOTAL3','1YR','2YR','3YR','TOTAL3']].set_index('Image Data ID')

# %%
df1to4 = df.join(up_df)

# %%
df1to4 = df1to4.dropna(axis=0,subset=(['1YR']))

# %%
df1to4
# Out:
#                  Group  Subject  Age Sex  \
# Image Data ID
# 360618         Control     3769   71   M
# 388617              PD     4122   64   M
# 363956              PD     3870   41   F
# 419581              PD     3829   68   F
# 341075         Control     3271   58   M
# 419660              PD     3431   64   F
# 339032         Control     4004   65   F
# 495329              PD     4111   76   M
# 340367              PD     3429   65   M
# 418918              PD     3500   51   F
# 341228              PD     3076   76   F
# 419568              PD     3528   60   F
# 418370              PD     3612   69   M
# 688469              PD     3089   58   F
# 388528         Control     3668   76   M
# 419597              PD     4059   48   F
# 446136              PD     3766   66   F
# 341042         Control     3206   31   F
# 358129              PD     3506   68   F
# 339040              PD     4012   51   F
# 419274              PD     3826   78   M
# 337832         Control     3850   50   F
# 767692              PD     3207   62   F
# 418661              PD     3218   65   M
# 363959              PD     4030   75   M
# 341214              PD     3060   75   M
# 418665              PD     3230   71   M
# 419569              PD     3540   65   M
# 418473              PD     3168   64   F
# 339552         Control     3554   75   M
# ...                ...      ...  ...  ..
# 913206              PD     3824   59   F
# 340418         Control     3106   71   F
# 436870              PD     3664   63   F
# 419254              PD     3586   64   M
# 355196              PD     3125   46   M
# 419275              PD     3868   70   M
# 767599              PD     3471   78   M
# 388620              PD     4124   71   M
# 388590              PD     4038   71   F
# 913227              PD     4106   76   M
# 341198         Control     3011   32   M
# 418700              PD     3770   56   F
# 340366         Control     3428   58   F
# 388544              PD     3793   68   M
# 419848              PD     3105   71   M
# 688473              PD     3385   54   M
# 419886              PD     3815   64   M
# 343870              PD     3781   72   M
# 446143              PD     4019   57   F
# 388511              PD     3482   54   M
# 770314              PD     3168   67   F
# 388490         Control     3237   70   F
# 343857              PD     3229   73   M
# 504431              PD     3233   39   M
# 419846              PD     3067   76   M
# 339546              PD     3528   59   F
# 495328              PD     4110   73   M
# 355954              PD     3557   60   M
# 358130              PD     3507   63   M
# 419244              PD     3180   62   F
#
#                                                        Filenames     TOTAL3  \
# Image Data ID
# 360618         ./PPMI 6/3769/Reconstructed_DaTSCAN/2012-10-25...   2.000000
# 388617         ./PPMI 6/4122/Reconstructed_DaTSCAN/2013-02-06...  26.000000
# 363956         ./PPMI 4/3870/Reconstructed_DaTSCAN/2012-11-29...   5.500000
# 419581         ./PPMI/3829/Reconstructed_DaTSCAN/2013-10-01_1...  19.250000
# 341075         ./PPMI 6/3271/Reconstructed_DaTSCAN/2011-09-13...   2.000000
# 419660         ./PPMI 3/3431/Reconstructed_DaTSCAN/2013-10-10...  12.000000
# 339032         ./PPMI 3.5/4004/Reconstructed_DaTSCAN/2011-09-...   0.000000
# 495329         ./PPMI 5/4111/Reconstructed_DaTSCAN/2015-01-13...  44.000000
# 340367         ./PPMI/3429/Reconstructed_DaTSCAN/2011-07-05_1...  13.000000
# 418918         ./PPMI 5/3500/Reconstructed_DaTSCAN/2012-11-15...  34.000000
# 341228         ./PPMI 3.5/3076/Reconstructed_DaTSCAN/2012-02-...  30.400000
# 419568         ./PPMI 2/3528/Reconstructed_DaTSCAN/2012-11-30...  22.250000
# 418370         ./PPMI 3.5/3612/Reconstructed_DaTSCAN/2012-06-...  22.500000
# 688469         ./PPMI 6/3089/Reconstructed_DaTSCAN/2015-05-19...  24.000000
# 388528         ./PPMI 6/3668/Reconstructed_DaTSCAN/2013-04-26...   0.000000
# 419597         ./PPMI 5/4059/Reconstructed_DaTSCAN/2013-09-04...  11.666667
# 446136         ./PPMI 7/3766/Reconstructed_DaTSCAN/2014-01-30...  18.333333
# 341042         ./PPMI 3/3206/Reconstructed_DaTSCAN/2011-07-21...   0.000000
# 358129         ./PPMI 5/3506/Reconstructed_DaTSCAN/2012-02-29...  25.500000
# 339040         ./PPMI 7/4012/Reconstructed_DaTSCAN/2011-11-10...  21.500000
# 419274         ./PPMI 6/3826/Reconstructed_DaTSCAN/2013-08-20...  12.000000
# 337832         ./PPMI 7/3850/Reconstructed_DaTSCAN/2011-03-31...   0.000000
# 767692         ./PPMI 2/3207/Reconstructed_DaTSCAN/2015-02-11...  23.500000
# 418661         ./PPMI 3.5/3218/Reconstructed_DaTSCAN/2012-11-...  34.500000
# 363959         ./PPMI 7/4030/Reconstructed_DaTSCAN/2012-11-28...  38.000000
# 341214         ./PPMI 9/3060/Reconstructed_DaTSCAN/2011-07-21...  19.250000
# 418665         ./PPMI 3/3230/Reconstructed_DaTSCAN/2013-07-25...  12.000000
# 419569         ./PPMI 4/3540/Reconstructed_DaTSCAN/2013-10-30...  24.000000
# 418473         ./PPMI 5/3168/Reconstructed_DaTSCAN/2012-10-09...  43.500000
# 339552         ./PPMI 6/3554/Reconstructed_DaTSCAN/2011-01-20...   2.000000
# ...                                                          ...        ...
# 913206         ./PPMI 4/3824/Reconstructed_DaTSCAN/2016-08-23...  19.000000
# 340418         ./PPMI 4/3106/Reconstructed_DaTSCAN/2011-08-10...   0.000000
# 436870         ./PPMI 3.5/3664/Reconstructed_DaTSCAN/2014-03-...  15.000000
# 419254         ./PPMI 7/3586/Reconstructed_DaTSCAN/2013-08-01...  27.500000
# 355196         ./PPMI 2/3125/Reconstructed_DaTSCAN/2012-06-14...  21.333333
# 419275         ./PPMI 3.5/3868/Reconstructed_DaTSCAN/2013-08-...  26.000000
# 767599         ./PPMI 5/3471/Reconstructed_DaTSCAN/2016-03-08...  40.500000
# 388620         ./PPMI 2/4124/Reconstructed_DaTSCAN/2013-02-22...  42.500000
# 388590         ./PPMI 5/4038/Reconstructed_DaTSCAN/2013-03-14...  30.750000
# 913227         ./PPMI/4106/Reconstructed_DaTSCAN/2016-12-14_1...  10.000000
# 341198         ./PPMI/3011/Reconstructed_DaTSCAN/2011-07-07_1...   0.000000
# 418700         ./PPMI 2/3770/Reconstructed_DaTSCAN/2013-02-27...  33.666667
# 340366         ./PPMI 4/3428/Reconstructed_DaTSCAN/2011-07-06...   0.000000
# 388544         ./PPMI 8/3793/Reconstructed_DaTSCAN/2013-02-26...  20.750000
# 419848         ./PPMI 2/3105/Reconstructed_DaTSCAN/2013-04-19...  48.000000
# 688473         ./PPMI 4/3385/Reconstructed_DaTSCAN/2015-05-15...        NaN
# 419886         ./PPMI 4/3815/Reconstructed_DaTSCAN/2013-11-05...  10.000000
# 343870         ./PPMI 7/3781/Reconstructed_DaTSCAN/2012-06-28...  16.666667
# 446143         ./PPMI 8/4019/Reconstructed_DaTSCAN/2014-03-07...  20.000000
# 388511         ./PPMI 3/3482/Reconstructed_DaTSCAN/2013-02-27...  13.400000
# 770314         ./PPMI/3168/Reconstructed_DaTSCAN/2015-10-14_1...  77.500000
# 388490         ./PPMI 7/3237/Reconstructed_DaTSCAN/2013-01-24...   2.000000
# 343857         ./PPMI 7/3229/Reconstructed_DaTSCAN/2012-06-27...  36.666667
# 504431         ./PPMI 3/3233/Reconstructed_DaTSCAN/2014-12-16...  13.000000
# 419846         ./PPMI 6/3067/Reconstructed_DaTSCAN/2013-06-07...  36.000000
# 339546         ./PPMI 3/3528/Reconstructed_DaTSCAN/2011-12-06...  24.000000
# 495328         ./PPMI 3.5/4110/Reconstructed_DaTSCAN/2015-02-...  30.000000
# 355954         ./PPMI 4/3557/Reconstructed_DaTSCAN/2012-01-17...  31.666667
# 358130         ./PPMI 7/3507/Reconstructed_DaTSCAN/2012-02-22...  18.000000
# 419244         ./PPMI 5/3180/Reconstructed_DaTSCAN/2013-07-31...  28.666667
#
#                      1YR        2YR        3YR     TOTAL3
# Image Data ID
# 360618          0.000000   0.000000   0.000000   2.000000
# 388617         18.333333  17.000000        NaN  26.000000
# 363956          9.333333  19.000000  44.500000   5.500000
# 419581         15.500000  11.000000  25.500000  19.250000
# 341075          7.000000        NaN        NaN   2.000000
# 419660         12.000000   9.500000  14.000000  12.000000
# 339032          4.000000   9.000000  11.000000   0.000000
# 495329         36.500000  52.500000  38.000000  44.000000
# 340367         14.000000  19.000000  26.500000  13.000000
# 418918         25.500000  30.500000  35.500000  34.000000
# 341228         40.500000  47.500000  51.500000  30.400000
# 419568         14.000000  18.500000  23.500000  22.250000
# 418370         13.000000   5.000000  10.500000  22.500000
# 688469         13.500000  17.500000  19.000000  24.000000
# 388528          0.000000        NaN   0.000000   0.000000
# 419597         24.000000  23.500000  27.500000  11.666667
# 446136         21.000000        NaN        NaN  18.333333
# 341042          0.000000   0.000000   0.000000   0.000000
# 358129         32.000000        NaN        NaN  25.500000
# 339040         29.000000  38.000000  36.000000  21.500000
# 419274         12.000000  23.000000  28.500000  12.000000
# 337832          0.000000   0.000000   0.000000   0.000000
# 767692         18.000000  16.000000  14.000000  23.500000
# 418661         30.000000  30.500000  37.000000  34.500000
# 363959         35.000000  39.500000  47.000000  38.000000
# 341214         23.000000   7.000000   8.500000  19.250000
# 418665         19.500000  28.000000  30.500000  12.000000
# 419569         28.000000  39.000000  46.000000  24.000000
# 418473         44.500000  63.500000  77.500000  43.500000
# 339552          0.000000   0.000000   2.000000   2.000000
# ...                  ...        ...        ...        ...
# 913206         22.000000        NaN        NaN  19.000000
# 340418          0.000000   2.000000   0.000000   0.000000
# 436870         13.000000  19.000000  22.500000  15.000000
# 419254         30.000000  26.000000  37.000000  27.500000
# 355196         23.000000  16.333333  11.000000  21.333333
# 419275         39.000000  32.000000        NaN  26.000000
# 767599         48.000000        NaN        NaN  40.500000
# 388620         26.000000  23.500000  36.500000  42.500000
# 388590         22.000000  21.500000  23.000000  30.750000
# 913227         10.000000  15.000000        NaN  10.000000
# 341198          0.000000   0.000000        NaN   0.000000
# 418700         31.500000  26.500000  41.500000  33.666667
# 340366          0.000000   0.000000   0.000000   0.000000
# 388544         23.666667  16.000000  20.000000  20.750000
# 419848         57.000000  66.000000        NaN  48.000000
# 688473         10.000000        NaN  12.333333        NaN
# 419886         23.000000  20.500000  32.500000  10.000000
# 343870         17.500000  20.000000  19.000000  16.666667
# 446143         18.500000  25.500000  18.000000  20.000000
# 388511         19.500000  21.500000  26.500000  13.400000
# 770314         80.500000        NaN        NaN  77.500000
# 388490          6.000000   3.000000   1.000000   2.000000
# 343857         25.000000  28.666667  50.000000  36.666667
# 504431         13.000000  26.000000  27.500000  13.000000
# 419846         34.500000  35.500000  40.000000  36.000000
# 339546         22.250000  14.000000  18.500000  24.000000
# 495328         39.000000  24.000000  32.000000  30.000000
# 355954         33.000000  36.000000  35.666667  31.666667
# 358130         19.000000  25.000000  33.000000  18.000000
# 419244         31.500000  48.000000  40.500000  28.666667
#
# [1391 rows x 10 columns]

# %%
df1to4.to_csv('comandfile.csv')

# %%
df1to4 = pd.read_csv('comandfile.csv')

# %%
df1to4 = df1to4[~df1to4.Group.str.contains('Control')]

# %%
df1to4 = df1to4[~df1to4.TOTAL3.isnull()]

# %%
df1to4.any().isnull()
# Out:
# Image Data ID    False
# Group            False
# Subject          False
# Age              False
# Sex              False
# Filenames        False
# TOTAL3           False
# 1YR              False
# 2YR              False
# 3YR              False
# TOTAL3.1         False
# dtype: bool

# %%
df1to4.loc[df1to4['Sex']=='F', 'Sex']=0
df1to4.loc[df1to4['Sex']=='M', 'Sex']=1

# %%
pro = (df1to4['1YR'].values - df1to4['TOTAL3'].values)
progress = []

for i in pro:
    if i > 2 : progress.append(-1)
    elif i < (-2) : progress.append(1)
    else : progress.append(0)
df1to4['Progress'] = progress
del(pro,progress)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale3 = MinMaxScaler()

# %%
print(scale3.fit(df1to4['TOTAL3'].values.reshape(-1,1)))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
df1to4['3scale'] = scale3.transform(df1to4['TOTAL3'].values.reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
X_train_tmp, X_test_tmp, param_train_tmp, param_test_tmp, y_train_tmp, y_test_tmp = train_test_split(df1to4, df1to4[['Sex','Age','3scale']], df1to4['1YR'], test_size=0.2)

from sklearn.model_selection import train_test_split
X_train_tmp, X_val_tmp, param_train_tmp, param_val_tmp, y_train_tmp, y_val_tmp = train_test_split(X_train_tmp, param_train_tmp, y_train_tmp, test_size=0.3)

# %%
lstFilesDCM_train = []  # create an empty list
lstFilesDCM_test = []
lstFilesDCM_val = []
lstFilesDCM_train = X_train_tmp['Filenames'].values
lstFilesDCM_train = lstFilesDCM_train.tolist()
lstFilesDCM_test = X_test_tmp['Filenames'].values
lstFilesDCM_test = lstFilesDCM_test.tolist()
lstFilesDCM_val = X_val_tmp['Filenames'].values
lstFilesDCM_val = lstFilesDCM_val.tolist()

# %% [markdown]
# For NORMAL Image

# %%
#Training Set

# %%
# loop through all the DICOM files
image_array_39_train =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_train.append(ds.pixel_array[39])
    image_array_39_train.append(ds.pixel_array[39][:,::-1])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)

# %%
# loop through all the DICOM files
image_array_40_train =[]

#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_train.append(ds.pixel_array[40])
    image_array_40_train.append(ds.pixel_array[40][:,::-1])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

# %%
# loop through all the DICOM files
image_array_41_train =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_train:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_train.append(ds.pixel_array[41])
    image_array_41_train.append(ds.pixel_array[41][:,::-1])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)

# %%
#Stack up to made RGB, so we can use pretrain model
image_array_train = []
image_array_train = np.vstack((image_array_39_train, image_array_40_train, image_array_41_train))

# %%
del(image_array_39_train, image_array_40_train, image_array_41_train)

# %%
image_array_train.shape
# Out:
# (4110, 109, 91)

# %%
image_array_train= image_array_train.astype('float64')

# %%
image_array_train -= image_array_train.min()
image_array_train /= (image_array_train.max()-image_array_train.min())

# %%
#Validation set

# %%
'''# loop through all the DICOM files
image_array_39_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_val.append(ds.pixel_array[39])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)'''

# loop through all the DICOM files
image_array_40_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_val.append(ds.pixel_array[40])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

'''# loop through all the DICOM files
image_array_41_val =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_val:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_val.append(ds.pixel_array[41])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)'''

#Stack up to made RGB, so we can use pretrain model
'''image_array_val = np.vstack((
    np.stack([image_array_39_val, image_array_39_val, image_array_39_val], axis=3),
    np.stack([image_array_40_val, image_array_40_val, image_array_40_val], axis=3),
    np.stack([image_array_41_val, image_array_41_val, image_array_41_val], axis=3)))'''

image_array_val = np.asarray(image_array_40_val, dtype='float64')
image_array_val -= image_array_val.min()
image_array_val /= (image_array_val.max()-image_array_val.min())
del(image_array_40_val)
image_array_val.shape
# Out:
# (294, 109, 91)

# %%
#Test set

# %%
'''# loop through all the DICOM files
image_array_39_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_39_test.append(ds.pixel_array[39])
    #For debug corrupted image
    #print(np.asarray(image_array_39_train).shape)'''

# loop through all the DICOM files
image_array_40_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_40_test.append(ds.pixel_array[40])
    #For debug corrupted image
    #print(np.asarray(image_array_40_train).shape)

'''# loop through all the DICOM files
image_array_41_test =[]
#for i in [38,39,40,41,42,43]:
for filenameDCM in lstFilesDCM_test:
    #print(lstFilesDCM_train.index(filenameDCM))
    # read the file
    ds = pydicom.read_file(filenameDCM)
    # store the raw image data
    image_array_41_test.append(ds.pixel_array[41])
    #For debug corrupted image
    #print(np.asarray(image_array_41_train).shape)'''

'''#Stack up to made RGB, so we can use pretrain model
image_array_test = np.vstack((
    np.stack([image_array_39_test, image_array_39_test, image_array_39_test], axis=3),
    np.stack([image_array_40_test, image_array_40_test, image_array_40_test], axis=3),
    np.stack([image_array_41_test, image_array_41_test, image_array_41_test], axis=3)))'''

image_array_test = np.asarray(image_array_40_test, dtype='float64')
image_array_test -= image_array_test.min()
image_array_test /= (image_array_test.max()-image_array_test.min())
del(image_array_40_test)
image_array_test.shape
# Out:
# (245, 109, 91)

# %%
#Check matched data-result by Image ID number
lstFilesDCM_test[0:5]
# Out:
# ['./PPMI 6/4051/Reconstructed_DaTSCAN/2013-05-17_12_22_41.0/S202956/PPMI_4051_NM_Reconstructed_DaTSCAN_Br_20140403144909164_1_S202956_I418713.dcm',
#  './PPMI 2/4022/Reconstructed_DaTSCAN/2013-03-28_13_54_41.0/S202955/PPMI_4022_NM_Reconstructed_DaTSCAN_Br_20140403144854844_1_S202955_I418712.dcm',
#  './PPMI 9/3061/Reconstructed_DaTSCAN/2015-03-27_14_20_09.0/S257671/PPMI_3061_NM_Reconstructed_DaTSCAN_Br_20150811084933612_1_S257671_I504834.dcm',
#  './PPMI 8/3589/Reconstructed_DaTSCAN/2015-02-18_15_30_45.0/S268023/PPMI_3589_NM_Reconstructed_DaTSCAN_Br_20150807124656976_1_S268023_I504434.dcm',
#  './PPMI 2/3631/Reconstructed_DaTSCAN/2012-08-15_13_50_43.0/S168152/PPMI_3631_NM_Reconstructed_DaTSCAN_Br_20130116125806193_1_S168152_I355220.dcm']

# %%
X_test_tmp[0:5]
# Out:
#       Image Data ID Group  Subject  Age  Sex  \
# 1140         418713    PD     4051   54    0
# 73           418712    PD     4022   49    1
# 489          504834    PD     3061   57    0
# 1049         504434    PD     3589   77    0
# 1153         355220    PD     3631   68    0
#
#                                               Filenames     TOTAL3   1YR  \
# 1140  ./PPMI 6/4051/Reconstructed_DaTSCAN/2013-05-17...  20.333333  18.0
# 73    ./PPMI 2/4022/Reconstructed_DaTSCAN/2013-03-28...  31.000000  24.5
# 489   ./PPMI 9/3061/Reconstructed_DaTSCAN/2015-03-27...  30.000000   6.0
# 1049  ./PPMI 8/3589/Reconstructed_DaTSCAN/2015-02-18...  23.500000  17.0
# 1153  ./PPMI 2/3631/Reconstructed_DaTSCAN/2012-08-15...  16.500000  17.5
#
#        2YR   3YR   TOTAL3.1  Progress    3scale
# 1140  23.5  26.5  20.333333         1  0.242826
# 73    30.5  32.0  31.000000         1  0.384106
# 489    5.0  14.0  30.000000         1  0.370861
# 1049   NaN   NaN  23.500000         1  0.284768
# 1153  24.0  21.0  16.500000         0  0.192053

# %%
df = pd.concat([df1to4,df1to4,df1to4])

# %%
df1to4 = df

# %%
df1to4.loc[df1to4['Group']=='Control']
# Out:
# Empty DataFrame
# Columns: [Image Data ID, Group, Subject, Age, Sex, Filenames, TOTAL3, 1YR, 2YR, 3YR, TOTAL3.1]
# Index: []

# %%
df1to4[df1to4.TOTAL3.isnull()]
# Out:
# Empty DataFrame
# Columns: [Image Data ID, Group, Subject, Age, Sex, Filenames, TOTAL3, 1YR, 2YR, 3YR, TOTAL3.1]
# Index: []

# %%
y_train = y_train_tmp.values
y_train = np.hstack((y_train,y_train,y_train))
y_train = np.hstack((y_train,y_train))
y_val = y_val_tmp.values
#y_val= np.hstack((y_val,y_val,y_val))
y_test = y_test_tmp.values
#y_val= np.hstack((y_val,y_val,y_val))

# %%
y_train.shape,y_val.shape,y_test.shape
# Out:
# ((4110,), (294,), (245,))

# %%
param_train = param_train_tmp.values
params = []
for i in param_train:
    stack = []
    stack.append(i)
    stack = stack*10
    params.append(stack)
param_train = np.asarray(params)
del(params)

# %%
param_val = param_val_tmp.values
params = []
for i in param_val:
    stack = []
    stack.append(i)
    stack = stack*10
    params.append(stack)
param_val = np.asarray(params)
del(params)

param_test = param_test_tmp.values
params = []
for i in param_test:
    stack = []
    stack.append(i)
    stack = stack*10
    params.append(stack)
param_test = np.asarray(params)
del(params)

# %%
#x6 Param match training Image
param_train = np.vstack((param_train,param_train,param_train))
param_train = np.vstack((param_train,param_train))

# %%
param_train.shape
# Out:
# (4110, 10, 3)

# %% [markdown]
# ### Load dataset

# %%
X_train = torch.utils.data.DataLoader(image_array_train, batch_size=64)
param_train = torch.utils.data.DataLoader(param_train, batch_size=64)
y_train = torch.utils.data.DataLoader(y_train, batch_size=64)
X_val = torch.utils.data.DataLoader(image_array_val, batch_size=64)
param_val = torch.utils.data.DataLoader(param_val, batch_size=64)
y_val = torch.utils.data.DataLoader(y_val, batch_size=64)
X_test = torch.utils.data.DataLoader(image_array_test, batch_size=64)
param_test = torch.utils.data.DataLoader(param_test, batch_size=64)
y_test = torch.utils.data.DataLoader(y_test, batch_size=64)

#del(image_array_train,image_array_val,image_array_test)
#del(X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp,param_train_tmp,param_val_tmp,param_test_tmp)

# %% [markdown]
# ### Darknet

# %%
def conv_layer(ni, nf, ks=3, stride=1):
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=ks, bias=False, stride=stride, padding=ks//2),
        nn.BatchNorm2d(nf, momentum=0.01),
        nn.LeakyReLU(negative_slope=0.1, inplace=False))

class ResLayer(nn.Module):
    def __init__(self, ni):
        super().__init__()
        self.conv1=conv_layer(ni, ni//2, ks=1)
        self.conv2=conv_layer(ni//2, ni, ks=3)
        
    def forward(self, x): return x.add_(self.conv2(self.conv1(x.clone())))

class Darknet(nn.Module):
    def make_group_layer(self, ch_in, num_blocks, stride=1):
        return [conv_layer(ch_in, ch_in*2,stride=stride)
               ] + [(ResLayer(ch_in*2)) for i in range(num_blocks)]

    def __init__(self, num_blocks, num_classes, nf=32):
        super().__init__()
        features = [conv_layer(1, nf, ks=3, stride=1)]
        for i,nb in enumerate(num_blocks):
            features += self.make_group_layer(nf, nb, stride=2-(i==1))
            nf *= 2                        
        features += [nn.AdaptiveAvgPool2d(1), Flatten()]        
        self.features = nn.Sequential(*features)
        fc1 = [nn.Linear(1054, 120), nn.BatchNorm1d(120, momentum=0.01), nn.LeakyReLU(negative_slope=0.1, inplace=False)]
        self.fc1 = nn.Sequential(*fc1)
        self.layers = nn.Sequential(nn.Linear(120,1))
        
    def forward(self, x, y):
        x = x.unsqueeze(1)
        x1 = self.features(x)
        x = torch.cat((x1,y[:,:,0],y[:,:,1],y[:,:,2]),1)
        x = self.fc1(x)
        #x = F.dropout(x, p=0.2, training=self.training)
        
        return self.layers(x)

# %%
m = Darknet([1,2,4,6,3], num_classes=1, nf=32)
m.double()
#m = nn.DataParallel(m, [1,2,3])
# Out:
# Darknet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (2): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (4): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (5): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (7): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (8): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (9): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (10): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (11): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (12): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (13): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (14): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (15): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (16): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (17): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (18): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (19): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (20): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (21): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (22): AdaptiveAvgPool2d(output_size=1)
#     (23): Flatten()
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1054, out_features=120, bias=True)
#     (1): BatchNorm1d(120, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.1)
#   )
#   (layers): Sequential(
#     (0): Linear(in_features=120, out_features=1, bias=True)
#   )
# )

# %%
optimizer = optim.RMSprop(m.parameters(), lr = 1e-3)
criterion = nn.MSELoss().cuda()
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.8)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = "cpu"
m.to(device)
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Train

# %%
losslog=[]
vallog=[]

# %%
def train(niter):
    for epoch in trange(niter):  # loop over the dataset multiple times
        running_loss = 0.0        

        m.train(True)
        scheduler.step()
        with tqdm(total=len(X_train)) as pbar:
            for i, (x, p, y) in enumerate(zip(X_train,param_train,y_train)):
                x,p,y = x.to(device), p.to(device),y.to(device)

                i += 1
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward + backward + optimize
                outputs = m(Variable(x),Variable(p))
                loss = criterion(outputs,Variable(y).unsqueeze(1))
                loss.backward()
                optimizer.step()

                pbar.update()

                # print statistics
                running_loss += loss.item()
                if i % 20 == 19:    # print every 20 mini-batches
                    print('[%d, %5d]  Train MSE loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 20))
                    losslog.append(running_loss/20)
                    running_loss = 0.0
                    
            #Eval
        with tqdm(total=len(X_val)) as pbar:
            with torch.no_grad():
                predicted =[]
                for i, ( x, p, y) in enumerate(zip(X_val,param_val,y_val)):
                    x,p,y = x.to(device), p.to(device),y.to(device)

                    # forward + backward + optimize
                    outputs = m(x,p)
                    pred = outputs.squeeze(1).cpu().numpy().tolist()
                    predicted.append(pred)
                    pbar.update()

                predicted = list(chain.from_iterable(predicted))
                valloss = ((predicted-y_val.dataset) **2).mean()
                #valloss = abs(predicted-y_val.dataset).sum()/len(y_val.dataset)
                vallog.append(valloss)
                print(f'Val MSE loss: {valloss}')
            
    print('Finished Training')
    return losslog,vallog

# %%
TT = train(4)
# Out:
#  29%|██▉       | 19/65 [07:30<18:48, 24.54s/it][1,    20]  Train MSE loss: 78.427
#  60%|██████    | 39/65 [15:41<10:37, 24.54s/it][1,    40]  Train MSE loss: 57.057
#  91%|█████████ | 59/65 [23:52<02:27, 24.55s/it][1,    60]  Train MSE loss: 55.787
# 100%|██████████| 65/65 [26:12<00:00, 22.64s/it]
# 100%|██████████| 5/5 [00:38<00:00,  7.29s/it]Val MSE loss: 60.46052493810378
#
#  29%|██▉       | 19/65 [07:30<18:47, 24.51s/it]t][2,    20]  Train MSE loss: 50.124
#  60%|██████    | 39/65 [15:41<10:38, 24.57s/it][2,    40]  Train MSE loss: 50.700
#  91%|█████████ | 59/65 [23:51<02:27, 24.53s/it][2,    60]  Train MSE loss: 50.780
# 100%|██████████| 65/65 [26:12<00:00, 22.62s/it]
# 100%|██████████| 5/5 [00:38<00:00,  7.29s/it]Val MSE loss: 59.46563513431262
#
#  29%|██▉       | 19/65 [07:30<18:48, 24.54s/it]  [3,    20]  Train MSE loss: 47.808
#  60%|██████    | 39/65 [15:41<10:37, 24.53s/it][3,    40]  Train MSE loss: 49.269
#  91%|█████████ | 59/65 [23:51<02:27, 24.54s/it][3,    60]  Train MSE loss: 51.317
# 100%|██████████| 65/65 [26:12<00:00, 22.64s/it]
# 100%|██████████| 5/5 [00:38<00:00,  7.29s/it]Val MSE loss: 59.48316266195287
#
#  29%|██▉       | 19/65 [07:30<18:47, 24.51s/it]t][4,    20]  Train MSE loss: 47.524
#  60%|██████    | 39/65 [15:41<10:38, 24.55s/it][4,    40]  Train MSE loss: 48.507
#  91%|█████████ | 59/65 [23:51<02:27, 24.54s/it][4,    60]  Train MSE loss: 49.604
# 100%|██████████| 65/65 [26:12<00:00, 22.63s/it]
# 100%|██████████| 5/5 [00:38<00:00,  7.29s/it]Val MSE loss: 57.86935320483723
#
# 100%|██████████| 4/4 [1:47:39<00:00, 1614.79s/it]Finished Training

# %%
vallog
# Out:
# [60.46052493810378, 59.46563513431262, 59.48316266195287, 57.86935320483723]

# %% [markdown]
# ## Validate

# %%
def test():
    with torch.no_grad():
        n = len(X_test)
        m.eval()
        predicted = []
        with tqdm(total=n) as pbar:
            for i, ( x, p, y) in enumerate(zip(X_test,param_test,y_test)):
                x,p,y = x.to(device), p.to(device),y.to(device)


                # forward + backward + optimize
                outputs = m(x,p)
                pred = outputs.squeeze(1).cpu().numpy().tolist()
                predicted.append(pred)
                pbar.update()
                
        predicted = list(chain.from_iterable(predicted))
        loss = ((predicted - y_test.dataset)**2).mean()
        #loss = abs(predicted-y_test.dataset).sum()/len(y_test.dataset)
        print(f'MSE loss: {loss}')
        df_y = pd.DataFrame(y_test.dataset,columns=['actual'])
        df_pred = pd.DataFrame(predicted,columns=['predicted'])
        df_pred = df_pred.join(df_y)
        sns.jointplot(x=df_pred['actual'], y=df_pred['predicted'])
        sns.distplot(y_test.dataset)
        sns.distplot(df_pred['predicted'])
    return df_pred, loss

# %%
TEST = test()
# Out:
# 100%|██████████| 4/4 [00:31<00:00,  7.81s/it]
# MSE loss: 61.40123820897825
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
TEST
# Out:
# (     predicted     actual
#  0    19.050704  18.000000
#  1    28.812631  24.500000
#  2    26.056681   6.000000
#  3    22.287531  17.000000
#  4    16.519141  17.500000
#  5    25.296548  27.000000
#  6    17.117555  17.333333
#  7    21.558951  18.500000
#  8    26.072324  16.000000
#  9    25.944011  14.000000
#  10   18.968668  33.000000
#  11   12.624036  12.333333
#  12   31.889288  38.000000
#  13   26.168389  27.500000
#  14   35.187307  41.000000
#  15   19.581584  34.500000
#  16   25.718684  40.500000
#  17   14.288343  11.500000
#  18   16.451609  21.500000
#  19   27.827756  17.500000
#  20   13.345018  10.000000
#  21   21.329546  19.800000
#  22   15.383031  12.000000
#  23   26.061802  21.500000
#  24   15.099618  11.666667
#  25   28.603724  27.000000
#  26   24.303338  33.333333
#  27   19.647294  24.500000
#  28   27.395453  32.000000
#  29   11.929139  10.750000
#  ..         ...        ...
#  215  20.511711  19.500000
#  216  11.928928   8.000000
#  217  24.865669  29.000000
#  218  33.168768  33.000000
#  219  11.348170   7.250000
#  220  42.320207  35.500000
#  221  47.151559  50.666667
#  222  15.792000   8.500000
#  223  32.065762  36.000000
#  224  29.590141  38.500000
#  225  25.079381  37.000000
#  226  40.789751  43.500000
#  227  20.336017  13.500000
#  228  37.534203  35.000000
#  229  18.885786  18.000000
#  230  19.012650  22.250000
#  231  14.048172  15.500000
#  232  16.951384  13.333333
#  233  14.090310  10.000000
#  234  19.520864  18.000000
#  235  13.949242  11.000000
#  236  13.714908  14.000000
#  237  18.191641  21.000000
#  238  13.002522  14.666667
#  239  21.666209  30.500000
#  240  32.072215  34.500000
#  241  22.710161  20.750000
#  242  19.614262  29.500000
#  243  41.872347  39.500000
#  244  13.046952  14.000000
#
#  [245 rows x 2 columns], 61.40123820897825)

# %%
model_save_path = './save_model/'

# %%
torch.save(m.state_dict(),'Age_Sex_TOTAL3norm_.pth')

# %%
m = Darknet([1,2,4,6,3], num_classes=1, nf=32)
m.double()
m.load_state_dict(torch.load('Age_Sex_TOTAL3norm_.pth'))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
m.to(device)
print(device)
# Out:
# cuda:0

# %%
sns.pairplot
# Out:
# <function seaborn.axisgrid.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='hist', markers=None, size=2.5, aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None)>

# %%
sns.distplot(y_pred)

# %%
sns.distplot(y_test)

# %% [markdown]
# ## MultiLabel

# %%
def conv_layer(ni, nf, ks=3, stride=1):
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=ks, bias=False, stride=stride, padding=ks//2),
        nn.BatchNorm2d(nf, momentum=0.01),
        nn.LeakyReLU(negative_slope=0.1, inplace=False))

class ResLayer(nn.Module):
    def __init__(self, ni):
        super().__init__()
        self.conv1=conv_layer(ni, ni//2, ks=1)
        self.conv2=conv_layer(ni//2, ni, ks=3)
        
    def forward(self, x): return x.add_(self.conv2(self.conv1(x.clone())))

class Darknet(nn.Module):
    def make_group_layer(self, ch_in, num_blocks, stride=1):
        return [conv_layer(ch_in, ch_in*2,stride=stride)
               ] + [(ResLayer(ch_in*2)) for i in range(num_blocks)]

    def __init__(self, num_blocks, num_classes, nf=32):
        super().__init__()
        features = [conv_layer(1, nf, ks=3, stride=1)]
        for i,nb in enumerate(num_blocks):
            features += self.make_group_layer(nf, nb, stride=2-(i==1))
            nf *= 2                        
        features += [nn.AdaptiveAvgPool2d(1), Flatten()]        
        self.features = nn.Sequential(*features)
        fc1 = [nn.Linear(1054, 120), nn.BatchNorm1d(120, momentum=0.01), nn.LeakyReLU(negative_slope=0.1, inplace=False)]
        self.fc1 = nn.Sequential(*fc1)
        self.layers = nn.Sequential(nn.Linear(120,num_classes))
        
    def forward(self, x, y):
        x = x.unsqueeze(1)
        x1 = self.features(x)
        x = torch.cat((x1,y[:,:,0],y[:,:,1],y[:,:,2]),1)
        x = self.fc1(x)
        x = F.relu(x)
        #x = F.dropout(x, p=0.2, training=self.training)
        return F.log_softmax(self.layers(x), dim=-1)

# %%
ml = Darknet([1,2,4,6,3], num_classes=3, nf=32)
ml.double()
#m = nn.DataParallel(m, [1,2,3])
# Out:
# Darknet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (2): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (4): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (5): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (7): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (8): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (9): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (10): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (11): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (12): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (13): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (14): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (15): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (16): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (17): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (18): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (19): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (20): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (21): ResLayer(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#     )
#     (22): AdaptiveAvgPool2d(output_size=1)
#     (23): Flatten()
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1054, out_features=120, bias=True)
#     (1): BatchNorm1d(120, eps=1e-05, momentum=0.01, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.1)
#   )
#   (layers): Sequential(
#     (0): Linear(in_features=120, out_features=3, bias=True)
#   )
# )

# %%
optimizer = optim.RMSprop(ml.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.5)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = "cpu"
ml.to(device)
print(device)

### Train

losslog=[]
vallog=[]

def train(niter):
    for epoch in trange(niter):  # loop over the dataset multiple times
        running_loss = 0.0        

        ml.train(True)
        scheduler.step()
        with tqdm(total=len(X_train)) as pbar:
            for i, (x, p, y) in enumerate(zip(X_train,param_train,y_train)):
                x,p,y = x.to(device), p.to(device),y.to(device)

                i += 1
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward + backward + optimize
                outputs = m(Variable(x),Variable(p))
                loss = criterion(outputs,Variable(y.long()).unsqueeze(1))
                loss.backward()
                optimizer.step()

                pbar.update()

                # print statistics
                running_loss += loss.item()
                if i % 20 == 19:    # print every 20 mini-batches
                    print('[%d, %5d]  Train MSE loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 20))
                    losslog.append(running_loss/20)
                    running_loss = 0.0
                    
            #Eval
        with tqdm(total=len(X_val)) as pbar:
            with torch.no_grad():
                predicted =[]
                for i, ( x, p, y) in enumerate(zip(X_val,param_val,y_val)):
                    x,p,y = x.to(device), p.to(device),y.to(device)

                    # forward + backward + optimize
                    outputs = m(x,p)
                    pred = outputs.squeeze(1).cpu().numpy().tolist()
                    predicted.append(pred)
                    pbar.update()

                predicted = list(chain.from_iterable(predicted))
                valloss = ((predicted-y_val.dataset) **2).mean()
                #valloss = abs(predicted-y_val.dataset).sum()/len(y_val.dataset)
                vallog.append(valloss)
                print(f'Val MSE loss: {valloss}')
            
    print('Finished Training')
    return losslog,vallog
# Out:
# cuda:0

# %%
MUL = train(1)
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-61-a640e40ac557> in <module>()
# ----> 1 MUL = train(1)
#
# <ipython-input-60-0dde1cf210f0> in train(niter)
#      28
#      29                 # forward + backward + optimize
# ---> 30                 outputs = m(Variable(x),Variable(p))
#      31                 loss = criterion(outputs,Variable(y.long()).unsqueeze(1))
#      32                 loss.backward()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-42-69f5ea9f4a24> in forward(self, x, y)
#      32     def forward(self, x, y):
#      33         x = x.unsqueeze(1)
# ---> 34         x1 = self.features(x)
#      35         x = torch.cat((x1,y[:,:,0],y[:,:,1],y[:,:,2]),1)
#      36         x = self.fc1(x)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      47         return F.batch_norm(
#      48             input, self.running_mean, self.running_var, self.weight, self.bias,
# ---> 49             self.training or not self.track_running_stats, self.momentum, self.eps)
#      50
#      51     def extra_repr(self):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1192     return torch.batch_norm(
#    1193         input, weight, bias, running_mean, running_var,
# -> 1194         training, momentum, eps, torch.backends.cudnn.enabled
#    1195     )
#    1196
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1524586445097/work/aten/src/THC/generic/THCStorage.cu:58
